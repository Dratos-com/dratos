# %%
import unittest
from datetime import datetime, date, time
import uuid
import ulid
import pyarrow as pa
import json
from data_object import DataObject, ArrowConversionError
from typing import List, Dict, Any
# Out:
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# Cell In[10], line 7
#       5 import pyarrow as pa
#       6 import json
# ----> 7 from data_object import DataObject, ArrowConversionError
#       8 from typing import List, Dict, Any
#
# File ~/git/dratos/Beta/beta/data/obj/data_object.py:32
#      28 class ArrowConversionError(DataObjectError):
#      29     """Raised when conversion to/from Arrow fails."""
# ---> 32 @dataclass
#      33 class DataObject(BaseModel):
#      34     """
#      35     Base class for all data objects in the system.
#      36     Provides common fields and methods for Arrow conversion and data manipulation.
#      37     """
#      39     __tablename__: ClassVar[str] = "objects"
#
# File ~/git/dratos/Beta/.venv/lib/python3.11/site-packages/pydantic/dataclasses.py:264, in dataclass(_cls, init, repr, eq, order, unsafe_hash, frozen, config, validate_on_init, kw_only, slots)
#     261     _pydantic_dataclasses.complete_dataclass(cls, config_wrapper, raise_errors=False, types_namespace=None)
#     262     return cls
# --> 264 return create_dataclass if _cls is None else create_dataclass(_cls)
#
# File ~/git/dratos/Beta/.venv/lib/python3.11/site-packages/pydantic/dataclasses.py:197, in dataclass.<locals>.create_dataclass(cls)
#     194 from ._internal._utils import is_model_class
#     196 if is_model_class(cls):
# --> 197     raise PydanticUserError(
#     198         f'Cannot create a Pydantic dataclass from {cls.__name__} as it is already a Pydantic model',
#     199         code='dataclass-on-model',
#     200     )
#     202 original_cls = cls
#     204 # if config is not explicitly provided, try to read it from the type
#
# PydanticUserError: Cannot create a Pydantic dataclass from DataObject as it is already a Pydantic model
#
# For further information visit https://errors.pydantic.dev/2.9/u/dataclass-on-model

# %%
suite = unittest.TestLoader().loadTestsFromTestCase(TestDataObject)

# Run the tests
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_create_data_object (__main__.TestDataObject.test_create_data_object) ... ERROR
# test_from_arrow (__main__.TestDataObject.test_from_arrow) ... ERROR
# test_from_arrow_batch (__main__.TestDataObject.test_from_arrow_batch) ... ERROR
# test_from_arrow_table (__main__.TestDataObject.test_from_arrow_table) ... ERROR
# test_from_json (__main__.TestDataObject.test_from_json) ... ERROR
# test_get_arrow_schema (__main__.TestDataObject.test_get_arrow_schema) ... ERROR
# test_invalid_arrow_conversion (__main__.TestDataObject.test_invalid_arrow_conversion) ... ERROR
# test_to_arrow (__main__.TestDataObject.test_to_arrow) ... ERROR
# test_to_arrow_batch (__main__.TestDataObject.test_to_arrow_batch) ... ERROR
# test_to_arrow_table (__main__.TestDataObject.test_to_arrow_table) ... ERROR
# test_to_dataframe (__main__.TestDataObject.test_to_dataframe) ... ERROR
# test_to_json (__main__.TestDataObject.test_to_json) ... ERROR
# test_to_json_schema (__main__.TestDataObject.test_to_json_schema) ... ERROR
#
# ======================================================================
# ERROR: test_create_data_object (__main__.TestDataObject.test_create_data_object)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ======================================================================
# ERROR: test_from_arrow (__main__.TestDataObject.test_from_arrow)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ======================================================================
# ERROR: test_from_arrow_batch (__main__.TestDataObject.test_from_arrow_batch)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ======================================================================
# ERROR: test_from_arrow_table (__main__.TestDataObject.test_from_arrow_table)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ======================================================================
# ERROR: test_from_json (__main__.TestDataObject.test_from_json)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ======================================================================
# ERROR: test_get_arrow_schema (__main__.TestDataObject.test_get_arrow_schema)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ======================================================================
# ERROR: test_invalid_arrow_conversion (__main__.TestDataObject.test_invalid_arrow_conversion)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ======================================================================
# ERROR: test_to_arrow (__main__.TestDataObject.test_to_arrow)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ======================================================================
# ERROR: test_to_arrow_batch (__main__.TestDataObject.test_to_arrow_batch)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ======================================================================
# ERROR: test_to_arrow_table (__main__.TestDataObject.test_to_arrow_table)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ======================================================================
# ERROR: test_to_dataframe (__main__.TestDataObject.test_to_dataframe)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ======================================================================
# ERROR: test_to_json (__main__.TestDataObject.test_to_json)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ======================================================================
# ERROR: test_to_json_schema (__main__.TestDataObject.test_to_json_schema)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/3y/zg7vxt8x3093z69km_lm4v5h0000gp/T/ipykernel_3037/126021702.py", line 3, in setUp
#     class TestObject(DataObject):
#      ^^^^^^^^^^
# NameError: name 'DataObject' is not defined
#
# ----------------------------------------------------------------------
# Ran 13 tests in 0.008s
#
# FAILED (errors=13)
# <unittest.runner.TextTestResult run=13 errors=13 failures=0>
